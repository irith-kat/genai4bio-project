# %%
from alphagenome.data import genome
from alphagenome.visualization import plot_components
from alphagenome_research.model import dna_model
import matplotlib.pyplot as plt

model = dna_model.create_from_huggingface('all_folds')

interval = genome.Interval(chromosome='chr22', start=35677410, end=36725986)
variant = genome.Variant(
    chromosome='chr22',
    position=36201698,
    reference_bases='A',
    alternate_bases='C',
)

outputs = model.predict_variant(
    interval=interval,
    variant=variant,
    ontology_terms=['UBERON:0001157'],
    requested_outputs=[dna_model.OutputType.RNA_SEQ],
)

plot_components.plot(
    [
        plot_components.OverlaidTracks(
            tdata={
                'REF': outputs.reference.rna_seq,
                'ALT': outputs.alternate.rna_seq,
            },
            colors={'REF': 'dimgrey', 'ALT': 'red'},
        ),
    ],
    interval=outputs.reference.rna_seq.interval.resize(2**15),
    # Annotate the location of the variant as a vertical line.
    annotations=[plot_components.VariantAnnotation([variant], alpha=0.8)],
)
plt.show()
# Out:
# Fetching 12 files: 100%|██████████| 12/12 [00:00<00:00, 213269.69it/s]
# /Users/irithkatiyar/Desktop/hst506/genai4bio-project/.venv/lib/python3.13/site-packages/pyfaidx/__init__.py:596: UserWarning: for fsspec: HTTPFileSystem assuming index is current
#   warnings.warn("for fsspec: %s assuming index is current" % type(self._fs).__name__)
# /Users/irithkatiyar/Desktop/hst506/genai4bio-project/.venv/lib/python3.13/site-packages/pyfaidx/__init__.py:596: UserWarning: for fsspec: HTTPFileSystem assuming index is current
#   warnings.warn("for fsspec: %s assuming index is current" % type(self._fs).__name__)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 6
#       2 from alphagenome.visualization import plot_components
#       3 from alphagenome_research.model import dna_model
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 model = dna_model.create_from_huggingface('all_folds')
#       7
#       8 interval = genome.Interval(chromosome='chr22', start=35677410, end=36725986)
#       9 variant = genome.Variant(
#
# File ~/Desktop/hst506/genai4bio-project/.venv/lib/python3.13/site-packages/alphagenome_research/model/dna_model.py:1378, in create_from_huggingface(model_version, organism_settings, device)
#    1373   model_version = model_version.name
#    1375 checkpoint_path = huggingface_hub.snapshot_download(
#    1376     repo_id=f'google/alphagenome-{model_version.replace("_", "-").lower()}'
#    1377 )
# -> 1378 return create(
#    1379     checkpoint_path, organism_settings=organism_settings, device=device
#    1380 )
#
# File ~/Desktop/hst506/genai4bio-project/.venv/lib/python3.13/site-packages/alphagenome_research/model/dna_model.py:1296, in create(checkpoint_path, organism_settings, model_settings, device)
#    1289 checkpointer = ocp.StandardCheckpointer()
#    1290 params, state = checkpointer.restore(
#    1291     checkpoint_path,
#    1292     target=target_shapes if validate_checkpoint else None,
#    1293     strict=validate_checkpoint,
#    1294 )
# -> 1296 return AlphaGenomeModel(
#    1297     params=params,
#    1298     state=state,
#    1299     apply_fn=apply_fn,
#    1300     junctions_apply_fn=junctions_apply_fn,
#    1301     metadata=metadata,
#    1302     fasta_extractors=fasta_extractors,
#    1303     splice_site_extractors=splice_site_extractors,
#    1304     gtfs=gtfs,
#    1305     pas_gtfs=pas_gtfs,
#    1306     num_splice_sites=model_settings.num_splice_sites,
#    1307     splice_site_threshold=model_settings.splice_site_threshold,
#    1308     device=device,
#    1309 )
#
# File ~/Desktop/hst506/genai4bio-project/.venv/lib/python3.13/site-packages/alphagenome_research/model/dna_model.py:387, in AlphaGenomeModel.__init__(self, params, state, apply_fn, junctions_apply_fn, metadata, fasta_extractors, splice_site_extractors, gtfs, pas_gtfs, num_splice_sites, splice_site_threshold, device)
#     385   device = jax.default_device.value or jax.local_devices()[0]
#     386   if device.platform not in {'gpu', 'tpu'}:
# --> 387     raise ValueError(
#     388         'Cannot find any GPU or TPU devices. We strondly recommend running'
#     389         ' on GPU or TPU, but if you wish to run on CPU, please explicitly'
#     390         ' pass the JAX device to run the model.'
#     391     )
#     392 self._device_context = _DeviceContextManager(device)
#     393 self._params = jax.device_put(params, device)
#
# ValueError: Cannot find any GPU or TPU devices. We strondly recommend running on GPU or TPU, but if you wish to run on CPU, please explicitly pass the JAX device to run the model.
