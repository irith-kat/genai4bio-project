# %% [markdown]
# Estimated runtime on local CPU: ~6 minute

# %%
import pandas as pd

# %%
GTF_FILE_PATH = 'data/metadata/alphagenome_gtf.parquet'

# %%
# AlphaGenome provides a reference GTF file for the human genome (hg38) that can be used to map gene names to genomic coordinates
gtf = pd.read_feather(
    'https://storage.googleapis.com/alphagenome/reference/gencode/'
    'hg38/gencode.v46.annotation.gtf.gz.feather'
)
# GTF files contain many different feature types (gene, transcript, exon, etc.)
gtf = gtf[gtf["Feature"] == "gene"] # Filter to only keep gene features
gtf.head()
# Out:
#    Chromosome   Source Feature  Start    End Score Strand Frame  \
# 0        chr1   HAVANA    gene  11868  14409     .      +     .
# 5        chr1   HAVANA    gene  12009  13670     .      +     .
# 13       chr1   HAVANA    gene  14695  24886     .      -     .
# 25       chr1  ENSEMBL    gene  17368  17436     .      -     .
# 28       chr1   HAVANA    gene  29553  31109     .      +     .
#
#               gene_id                           gene_type  ...  \
# 0   ENSG00000290825.1                              lncRNA  ...
# 5   ENSG00000223972.6  transcribed_unprocessed_pseudogene  ...
# 13  ENSG00000227232.6              unprocessed_pseudogene  ...
# 25  ENSG00000278267.1                               miRNA  ...
# 28  ENSG00000243485.5                              lncRNA  ...
#
#    havana_transcript exon_number exon_id     hgnc_id           havana_gene  \
# 0               None        None    None        None                  None
# ...

# %%
gtf.to_parquet(GTF_FILE_PATH)
